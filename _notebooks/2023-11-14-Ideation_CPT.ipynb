# %% [markdown]
# ---
# toc: true
# comments: false
# layout: post
# title: CPT Warmup Ideation and Design
# type: hacks
# courses: { compsci: {week: } }
# ---

# %% [markdown]
# - Purpose
#     - Like a social media platform, but smaller and made for students
#         - Several main features
#             - Chat messaging
#                 - Or blogging
#             - Reactions
#             - “Stories” where you can blog your qualifications
#                 - Feedback from students or others
#             - Client-side theme changing?
#                 - Change colors (ex: light mode, dark mode, other colors)
#             - Sign-in feature
# - Code
#     - Binary

# %% [markdown]
# ### UI Design
#
# ![1.png](attachment:1.png)
#
# - Main
#     - Sidebar
#         - Messaging
#             - DM users
#         - Notifications
#         - “Stories”/blogs with posted info

# %% [markdown]
# ![2.png](attachment:2.png)
#
# - Sign-in feature

# %% [markdown]
# Grade: 0.95/1
# Well thought out and could be very useful if popular. It is a great way for students to communicate and socialize and ask for help, I can see myself using it. The have UIs to show there idea and have it well thought out. It connects with the idea of the porject and can see this achieving amazing things.
