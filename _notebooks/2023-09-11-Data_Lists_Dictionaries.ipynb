# %% [markdown]
# ---
# toc: true
# comments: false
# layout: post
# title: Lists/Dictionaries
# description: Data Types, Lists, and Dictionaries
# type: hacks
# courses: { compsci: {week: 4} }
# ---
