# %% [markdown]
# ---
# toc: False
# layout: post
# comments: true
# hide: False
# title: Trimester 2 MCQ Reflection
# description: Reflection for Tri 2 MCQ with Correction:::s and journey/learning.
# courses: {'compsci': {'week': 17}}
# type: tangibles
# ---

# %% [markdown]
# # Journey, Learning, & Discovery
# ### Quiz Notes
#
# Below are notes I filled out as I completed the MCQ. I did the same last Trimester, writing down researched definitions and meanings/significance of various computer science terms or topics I discovered on the MCQ. Research was either sourced from just Googling topic or utilizing ChatGPT to research.
#
# -

# %% [markdown]
# # Corrections
#
# Each number listed before the question for each correction represents the same corresponding question on the MCQ.
#
# Q1.
#
# [image]
#
# Correction:
#
# Q3.
#
# [image]
#
# Correction:
#
# Q10.
#
# [image]
#
# Correction:
#
# Q11.
#
# [image]
#
# Correction:
#
# Q16.
#
# [image]
#
# Correction:
#
# Q37.
#
# [image]
#
# Correction:
#
# Q39.
#
# [image]
#
# Correction:
#
# Q50.
#
# [image]
#
# Correction:
#
# Q56.
#
# [image]
#
# Correction:
#
# Q58.
#
# [image]
#
# Correction:
#
# Q59.
#
# [image]
#
# Correction:
#
# Q60.
#
# [image]
#
# Correction:
#
# Q62.
#
# [image]
#
# Correction:
#
# Q65.
#
# [image]
#
# Correction:
#
# Q66.
#
# [image]
#
# Correction:
